# %% [markdown]
# # Prediction: XGBoost Classifier
#
# > **Warning!** Please run `01_cleaning.ipynb` first if you haven't already

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from functions.constants import BM_NAME, STARTDATE, ENDDATE, N_THRESHOLD_BPS,DATA_DIR
from functions.helper_fns import * 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import seaborn as sns

# %%
active_returns_path = DATA_DIR + BM_NAME + "_active_returns.csv"
active_returns = pd.read_csv(active_returns_path, index_col=0, parse_dates=True)
print("Loaded active returns from", active_returns_path)
active_returns_thresholded_path = DATA_DIR + BM_NAME + "_active_returns_thresholded_" + str(N_THRESHOLD_BPS) + "bps.csv"
active_returns_thresholded = pd.read_csv(active_returns_thresholded_path, index_col=0, parse_dates=True)
print("Loaded active returns thresholded from", active_returns_thresholded_path)
# Out:
# Loaded active returns from ./../data/SP500_active_returns.csv
# Loaded active returns thresholded from ./../data/SP500_active_returns_thresholded_100bps.csv

# %%
NUM_FEATURES = 12
PREDICTION_PERIOD = "1w"
MODEL_USING_DF = active_returns
# MODEL_USING_DF = test_ticker_df #turn this on to run for one company
df = featurize_time_series(MODEL_USING_DF, PREDICTION_PERIOD, NUM_FEATURES,set_threshold_for_target_var_bps=N_THRESHOLD_BPS)
target_var = "ar_" + PREDICTION_PERIOD + "_t"
X = df.drop(columns=[target_var, "Date", "Ticker"])
y = df[[target_var]]
print("X shape:", X.shape)
print(X.head())
print("y shape:", y.shape)
print(y.head())
X = X.to_numpy()
y = y.to_numpy()
# Out:
# X shape: (249991, 12)
#     ar_1w_t_minus_1  ar_1w_t_minus_2  ar_1w_t_minus_3  ar_1w_t_minus_4  \
# 12         0.008647        -0.008387         0.008395         0.030798
# 13        -0.020086         0.008647        -0.008387         0.008395
# 14         0.022483        -0.020086         0.008647        -0.008387
# 15         0.017339         0.022483        -0.020086         0.008647
# 16         0.005448         0.017339         0.022483        -0.020086
#
#     ar_1w_t_minus_5  ar_1w_t_minus_6  ar_1w_t_minus_7  ar_1w_t_minus_8  \
# 12         0.006078        -0.007792         0.012361         0.018158
# 13         0.030798         0.006078        -0.007792         0.012361
# 14         0.008395         0.030798         0.006078        -0.007792
# 15        -0.008387         0.008395         0.030798         0.006078
# 16         0.008647        -0.008387         0.008395         0.030798
#
#     ar_1w_t_minus_9  ar_1w_t_minus_10  ar_1w_t_minus_11  ar_1w_t_minus_12
# 12        -0.040724         -0.000753         -0.015568         -0.005181
# 13         0.018158         -0.040724         -0.000753         -0.015568
# 14         0.012361          0.018158         -0.040724         -0.000753
# 15        -0.007792          0.012361          0.018158         -0.040724
# 16         0.006078         -0.007792          0.012361          0.018158
# y shape: (249991, 1)
#     ar_1w_t
# 12        0
# 13        1
# 14        1
# 15        0
# 16        0

# %%
TEST_FRACTION = 0.2
EVAL_FRACTION = 0.2
X_train_and_eval, X_test, y_train_and_eval, y_test = train_test_split(X, y, test_size=TEST_FRACTION, shuffle=False)
X_train, X_eval, y_train, y_eval = train_test_split(X_train_and_eval, y_train_and_eval, test_size=EVAL_FRACTION/(1-TEST_FRACTION), shuffle=False)
print("X_train shape:", X_train.shape)
print("X_eval shape:", X_eval.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_eval shape:", y_eval.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (149994, 12)
# X_eval shape: (49998, 12)
# X_test shape: (49999, 12)
# y_train shape: (149994, 1)
# y_eval shape: (49998, 1)
# y_test shape: (49999, 1)

# %% [markdown]
# ## Train a XGBoost

# %%
# Import XGBoost
from xgboost import XGBClassifier

# Initialize XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Train the XGBoost model
xgb_model.fit(X_train, y_train)

# Evaluate the model
train_score = xgb_model.score(X_train, y_train)
eval_score = xgb_model.score(X_eval, y_eval)
test_score = xgb_model.score(X_test, y_test)

print("Training accuracy:", train_score)
print("Evaluation accuracy:", eval_score)
print("Test accuracy:", test_score)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [15:07:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training accuracy: 0.6979012493833087
# Evaluation accuracy: 0.6453658146325854
# Test accuracy: 0.6579131582631652

# %%
# Import XGBoost
from xgboost import XGBClassifier

# Initialize XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Train the XGBoost model
xgb_model.fit(X_train, y_train)

# Evaluate the model
train_score = xgb_model.score(X_train, y_train)
eval_score = xgb_model.score(X_eval, y_eval)
test_score = xgb_model.score(X_test, y_test)

print("Training accuracy:", train_score)
print("Evaluation accuracy:", eval_score)
print("Test accuracy:", test_score)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [15:07:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Training accuracy: 0.6979012493833087
# Evaluation accuracy: 0.6453658146325854
# Test accuracy: 0.6579131582631652

# %%
y_pred = xgb_model.predict(X_eval)\
y_pred_proba = xgb_model.predict_proba(X_eval)
y_train_pred = xgb_model.predict(X_train)
y_train_pred_proba = xgb_model.predict_proba(X_train)
print("===TRAINING SET===")
evaluate_model_performance(y_train, y_train_pred, y_train_pred_proba,PREDICTION_PERIOD,NUM_FEATURES,plot_confusion_matrix=False)
print("===EVALUATION SET===")
evaluate_model_performance(y_eval, y_pred, y_pred_proba,PREDICTION_PERIOD,NUM_FEATURES)
# Out:
# ===TRAINING SET===
# Accuracy: 0.6979012493833087
# Precision: 0.8559823488115536
# Recall: 0.16284438678165306
# F1: 0.27363223955244215
# ROC AUC: 0.7265909909776842
# ===EVALUATION SET===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5 evaluate_model_performance(y_train, y_train_pred, y_train_pred_proba,PREDICTION_PERIOD,NUM_FEATURES,plot_confusion_matrix=False)
#       6 print("===EVALUATION SET===")
# ----> 7 evaluate_model_performance(y_eval, y_pred, y_pred_proba,PREDICTION_PERIOD,NUM_FEATURES)
#
# NameError: name 'y_pred_proba' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# Define the hyperparameter grid for XGBoost
param_grid = {
    'max_depth': [3, 6, 9],  # Tree depth
    'learning_rate': [0.01, 0.1, 0.2],  # Step size
    'n_estimators': [50, 100, 200],  # Number of boosting rounds
    'subsample': [0.6, 0.8, 1.0],  # Fraction of samples for training each tree
    'colsample_bytree': [0.6, 0.8, 1.0]  # Fraction of features for each tree
}

# Initialize the XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Perform GridSearchCV to find the best parameters
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    cv=3,  # 3-fold cross-validation
    scoring='accuracy',  # Optimize for accuracy
    verbose=1
)
33
# Fit the grid search on the training data
grid_search.fit(X_train, y_train)

# Extract the best model and parameters
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

best_params
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:54:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [14:55:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      24 33
#      25 # Fit the grid search on the training data
# ---> 26 grid_search.fit(X_train, y_train)
#      28 # Extract the best model and parameters
#      29 best_model = grid_search.best_estimator_
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:910, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     907 result["fit_error"] = None
#     909 fit_time = time.time() - start_time
# --> 910 test_scores = _score(
#     911     estimator, X_test, y_test, scorer, score_params_test, error_score
#     912 )
#     913 score_time = time.time() - start_time - fit_time
#     914 if return_train_score:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:971, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     969         scores = scorer(estimator, X_test, **score_params)
#     970     else:
# --> 971         scores = scorer(estimator, X_test, y_test, **score_params)
#     972 except Exception:
#     973     if isinstance(scorer, _MultimetricScorer):
#     974         # If `_MultimetricScorer` raises exception, the `error_score`
#     975         # parameter is equal to "raise".
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:279, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     276 if sample_weight is not None:
#     277     _kwargs["sample_weight"] = sample_weight
# --> 279 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:371, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     369 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     370 response_method = _check_response_method(estimator, self._response_method)
# --> 371 y_pred = method_caller(
#     372     estimator, response_method.__name__, X, pos_label=pos_label
#     373 )
#     375 scoring_kwargs = {**self._kwargs, **kwargs}
#     376 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:89, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      86 if cache is not None and response_method in cache:
#      87     return cache[response_method]
# ---> 89 result, _ = _get_response_values(
#      90     estimator, *args, response_method=response_method, **kwargs
#      91 )
#      93 if cache is not None:
#      94     cache[response_method] = result
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/_response.py:211, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     208     elif pos_label is None and target_type == "binary":
#     209         pos_label = classes[-1]
# --> 211 y_pred = prediction_method(X)
#     213 if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     214     y_pred = _process_predict_proba(
#     215         y_pred=y_pred,
#     216         target_type=target_type,
#     217         classes=classes,
#     218         pos_label=pos_label,
#     219     )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1565, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1556 def predict(
#    1557     self,
#    1558     X: ArrayLike,
#    (...)
#    1562     iteration_range: Optional[IterationRange] = None,
#    1563 ) -> ArrayLike:
#    1564     with config_context(verbosity=self.verbosity):
# -> 1565         class_probs = super().predict(
#    1566             X=X,
#    1567             output_margin=output_margin,
#    1568             validate_features=validate_features,
#    1569             base_margin=base_margin,
#    1570             iteration_range=iteration_range,
#    1571         )
#    1572         if output_margin:
#    1573             # If output_margin is active, simply return the scores
#    1574             return class_probs
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/xgboost/core.py:2534, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2530     from .data import _ensure_np_dtype
#    2532     data, _ = _ensure_np_dtype(data, data.dtype)
#    2533     _check_call(
# -> 2534         _LIB.XGBoosterPredictFromDense(
#    2535             self.handle,
#    2536             _array_interface(data),
#    2537             args,
#    2538             p_handle,
#    2539             ctypes.byref(shape),
#    2540             ctypes.byref(dims),
#    2541             ctypes.byref(preds),
#    2542         )
#    2543     )
#    2544     return _prediction_output(shape, dims, preds, False)
#    2545 if isinstance(data, PandasTransformed):
#
# KeyboardInterrupt:

# %%
# Train the XGBoost model with the best parameters
optimized_model = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.1,
    max_depth=6,
    n_estimators=50,
    subsample=0.6,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

# Fit the model on the training data
optimized_model.fit(X_train, y_train)

# Evaluate the model
train_accuracy = optimized_model.score(X_train, y_train)
eval_accuracy = optimized_model.score(X_eval, y_eval)
test_accuracy = optimized_model.score(X_test, y_test)

# Print the results
print("Training Accuracy:", train_accuracy)
print("Evaluation Accuracy:", eval_accuracy)
print("Test Accuracy:", test_accuracy)
